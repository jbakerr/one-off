# %% [markdown]
# # Heising-Simons Proposal Data

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from datetime import datetime
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from ct_snippets.load_sf_class import SF_SOQL, SF_Report
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

# %%
df = pd.read_pickle("../data/interim/data.pkl")

# %% [markdown]
# ### Breakdown of AY 2019-20 Students Who Are Dreamers - By Student Type

# %%
prev_year_df = df[~pd.isna(df.AY2019_20_Student)]


prev_year_student_type = prev_year_df.pivot_table(
    index=["Site", "AY2019_20_Student"],
    columns="Dreamer",
    values="C_Id",
    aggfunc="count",
    dropna=True,
    margins=True,
    fill_value=0,
)
prev_year_student_type
# Out:
# Dreamer                                     No  Yes   All
# Site              AY2019_20_Student
# Aurora            High School Student      212    4   216
#                   Post-Secondary Student   132   10   142
# Boyle Heights     High School Student      243   15   258
#                   Post-Secondary Student   135   28   163
# Denver            High School Student       72    0    72
# East Palo Alto    High School Student      214    4   218
#                   Post-Secondary Student   136   22   158
# New Orleans       High School Student      219    6   225
#                   Post-Secondary Student   164    3   167
# Oakland           High School Student      259    4   263
#                   Post-Secondary Student   204    8   212
# Sacramento        High School Student      199    2   201
#                   Post-Secondary Student    67    2    69
# San Francisco     High School Student      220    8   228
#                   Post-Secondary Student   233   11   244
# The Durant Center High School Student      127    0   127
# Ward 8            High School Student       63    0    63
# Watts             High School Student      203    5   208
#                   Post-Secondary Student    36    3    39
# All                                       3138  135  3273

# %% [markdown]
# ### Percent of AY 2019-20 Students Who Are Dreamers

# %%
prev_year_student_type_percent = pd.crosstab(
    [prev_year_df.Site], prev_year_df.Dreamer, normalize="index", margins=True
).style.format("{:.0%}")

prev_year_student_type_percent
# Out:
# <style  type="text/css" >
# </style><table id="T_cefb7f92_027f_11eb_ba31_4c327597d7ef" ><thead>    <tr>        <th class="index_name level0" >Dreamer</th>        <th class="col_heading level0 col0" >No</th>        <th class="col_heading level0 col1" >Yes</th>    </tr>    <tr>        <th class="index_name level0" >Site</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cefb7f92_027f_11eb_ba31_4c327597d7eflevel0_row0" class="row_heading level0 row0" >Aurora</th>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow0_col0" class="data row0 col0" >96%</td>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow0_col1" class="data row0 col1" >4%</td>
#             </tr>
#             <tr>
#                         <th id="T_cefb7f92_027f_11eb_ba31_4c327597d7eflevel0_row1" class="row_heading level0 row1" >Boyle Heights</th>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow1_col0" class="data row1 col0" >90%</td>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow1_col1" class="data row1 col1" >10%</td>
#             </tr>
#             <tr>
#                         <th id="T_cefb7f92_027f_11eb_ba31_4c327597d7eflevel0_row2" class="row_heading level0 row2" >Denver</th>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow2_col0" class="data row2 col0" >100%</td>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow2_col1" class="data row2 col1" >0%</td>
#             </tr>
#             <tr>
#                         <th id="T_cefb7f92_027f_11eb_ba31_4c327597d7eflevel0_row3" class="row_heading level0 row3" >East Palo Alto</th>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow3_col0" class="data row3 col0" >93%</td>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow3_col1" class="data row3 col1" >7%</td>
#             </tr>
#             <tr>
#                         <th id="T_cefb7f92_027f_11eb_ba31_4c327597d7eflevel0_row4" class="row_heading level0 row4" >New Orleans</th>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow4_col0" class="data row4 col0" >98%</td>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow4_col1" class="data row4 col1" >2%</td>
#             </tr>
#             <tr>
#                         <th id="T_cefb7f92_027f_11eb_ba31_4c327597d7eflevel0_row5" class="row_heading level0 row5" >Oakland</th>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow5_col0" class="data row5 col0" >97%</td>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow5_col1" class="data row5 col1" >3%</td>
#             </tr>
#             <tr>
#                         <th id="T_cefb7f92_027f_11eb_ba31_4c327597d7eflevel0_row6" class="row_heading level0 row6" >Sacramento</th>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow6_col0" class="data row6 col0" >99%</td>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow6_col1" class="data row6 col1" >1%</td>
#             </tr>
#             <tr>
#                         <th id="T_cefb7f92_027f_11eb_ba31_4c327597d7eflevel0_row7" class="row_heading level0 row7" >San Francisco</th>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow7_col0" class="data row7 col0" >96%</td>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow7_col1" class="data row7 col1" >4%</td>
#             </tr>
#             <tr>
#                         <th id="T_cefb7f92_027f_11eb_ba31_4c327597d7eflevel0_row8" class="row_heading level0 row8" >The Durant Center</th>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow8_col0" class="data row8 col0" >100%</td>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow8_col1" class="data row8 col1" >0%</td>
#             </tr>
#             <tr>
#                         <th id="T_cefb7f92_027f_11eb_ba31_4c327597d7eflevel0_row9" class="row_heading level0 row9" >Ward 8</th>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow9_col0" class="data row9 col0" >100%</td>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow9_col1" class="data row9 col1" >0%</td>
#             </tr>
#             <tr>
#                         <th id="T_cefb7f92_027f_11eb_ba31_4c327597d7eflevel0_row10" class="row_heading level0 row10" >Watts</th>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow10_col0" class="data row10 col0" >97%</td>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow10_col1" class="data row10 col1" >3%</td>
#             </tr>
#             <tr>
#                         <th id="T_cefb7f92_027f_11eb_ba31_4c327597d7eflevel0_row11" class="row_heading level0 row11" >All</th>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow11_col0" class="data row11 col0" >96%</td>
#                         <td id="T_cefb7f92_027f_11eb_ba31_4c327597d7efrow11_col1" class="data row11 col1" >4%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Current AY Dreamer Breakdown By Student Type

# %%
current_year_df = df[df.status.isin(["High School Student", "Post-Secondary Student"])]


current_year_student_type = current_year_df.pivot_table(
    index=["Site", "status"],
    columns="Dreamer",
    values="C_Id",
    aggfunc="count",
    dropna=True,
    margins=True,
    fill_value=0,
)

current_year_student_type
# Out:
# Dreamer                                     No  Yes   All
# Site              status
# Aurora            High School Student      172    1   173
#                   Post-Secondary Student   168   13   181
# Boyle Heights     High School Student      197    6   203
#                   Post-Secondary Student   165   34   199
# Denver            High School Student       54    0    54
#                   Post-Secondary Student     9    0     9
# East Palo Alto    High School Student      173    2   175
#                   Post-Secondary Student   156   22   178
# New Orleans       High School Student      159    2   161
#                   Post-Secondary Student   208    8   216
# Oakland           High School Student      192    3   195
#                   Post-Secondary Student   265   12   277
# Sacramento        High School Student      151    2   153
#                   Post-Secondary Student   111    2   113
# San Francisco     High School Student      152    2   154
#                   Post-Secondary Student   291   18   309
# The Durant Center High School Student      138    0   138
# Ward 8            High School Student       60    0    60
# Watts             High School Student      163    2   165
#                   Post-Secondary Student    71    6    77
# All                                       3055  135  3190

# %% [markdown]
# ### Current Year Dreamer Percentage

# %%
current_year_student_type_percent = pd.crosstab(
    [current_year_df.Site], current_year_df.Dreamer, normalize="index", margins=True
).style.format("{:.0%}")

current_year_student_type_percent
# Out:
# <style  type="text/css" >
# </style><table id="T_70d6adc8_0280_11eb_ba31_4c327597d7ef" ><thead>    <tr>        <th class="index_name level0" >Dreamer</th>        <th class="col_heading level0 col0" >No</th>        <th class="col_heading level0 col1" >Yes</th>    </tr>    <tr>        <th class="index_name level0" >Site</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_70d6adc8_0280_11eb_ba31_4c327597d7eflevel0_row0" class="row_heading level0 row0" >Aurora</th>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow0_col0" class="data row0 col0" >96%</td>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow0_col1" class="data row0 col1" >4%</td>
#             </tr>
#             <tr>
#                         <th id="T_70d6adc8_0280_11eb_ba31_4c327597d7eflevel0_row1" class="row_heading level0 row1" >Boyle Heights</th>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow1_col0" class="data row1 col0" >90%</td>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow1_col1" class="data row1 col1" >10%</td>
#             </tr>
#             <tr>
#                         <th id="T_70d6adc8_0280_11eb_ba31_4c327597d7eflevel0_row2" class="row_heading level0 row2" >Denver</th>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow2_col0" class="data row2 col0" >100%</td>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow2_col1" class="data row2 col1" >0%</td>
#             </tr>
#             <tr>
#                         <th id="T_70d6adc8_0280_11eb_ba31_4c327597d7eflevel0_row3" class="row_heading level0 row3" >East Palo Alto</th>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow3_col0" class="data row3 col0" >93%</td>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow3_col1" class="data row3 col1" >7%</td>
#             </tr>
#             <tr>
#                         <th id="T_70d6adc8_0280_11eb_ba31_4c327597d7eflevel0_row4" class="row_heading level0 row4" >New Orleans</th>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow4_col0" class="data row4 col0" >97%</td>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow4_col1" class="data row4 col1" >3%</td>
#             </tr>
#             <tr>
#                         <th id="T_70d6adc8_0280_11eb_ba31_4c327597d7eflevel0_row5" class="row_heading level0 row5" >Oakland</th>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow5_col0" class="data row5 col0" >97%</td>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow5_col1" class="data row5 col1" >3%</td>
#             </tr>
#             <tr>
#                         <th id="T_70d6adc8_0280_11eb_ba31_4c327597d7eflevel0_row6" class="row_heading level0 row6" >Sacramento</th>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow6_col0" class="data row6 col0" >98%</td>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow6_col1" class="data row6 col1" >2%</td>
#             </tr>
#             <tr>
#                         <th id="T_70d6adc8_0280_11eb_ba31_4c327597d7eflevel0_row7" class="row_heading level0 row7" >San Francisco</th>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow7_col0" class="data row7 col0" >96%</td>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow7_col1" class="data row7 col1" >4%</td>
#             </tr>
#             <tr>
#                         <th id="T_70d6adc8_0280_11eb_ba31_4c327597d7eflevel0_row8" class="row_heading level0 row8" >The Durant Center</th>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow8_col0" class="data row8 col0" >100%</td>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow8_col1" class="data row8 col1" >0%</td>
#             </tr>
#             <tr>
#                         <th id="T_70d6adc8_0280_11eb_ba31_4c327597d7eflevel0_row9" class="row_heading level0 row9" >Ward 8</th>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow9_col0" class="data row9 col0" >100%</td>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow9_col1" class="data row9 col1" >0%</td>
#             </tr>
#             <tr>
#                         <th id="T_70d6adc8_0280_11eb_ba31_4c327597d7eflevel0_row10" class="row_heading level0 row10" >Watts</th>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow10_col0" class="data row10 col0" >97%</td>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow10_col1" class="data row10 col1" >3%</td>
#             </tr>
#             <tr>
#                         <th id="T_70d6adc8_0280_11eb_ba31_4c327597d7eflevel0_row11" class="row_heading level0 row11" >All</th>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow11_col0" class="data row11 col0" >96%</td>
#                         <td id="T_70d6adc8_0280_11eb_ba31_4c327597d7efrow11_col1" class="data row11 col1" >4%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Alumni Dreamer Breakdown

# %%
alumni = df[df.status == "Alumni"]


alumni_percent = pd.crosstab([alumni.Site], alumni.Dreamer, margins=True)
alumni_percent
# Out:
# Dreamer          No  Yes  All
# Site
# Aurora           38    2   40
# Boyle Heights    11    3   14
# East Palo Alto  220   42  262
# New Orleans      63    2   65
# Oakland         202   16  218
# San Francisco   162    3  165
# All             696   68  764

# %%
# %%html
#
# <script>
# $(document).ready(function(){
#     window.code_toggle = function() {
#         (window.code_shown) ? $('div.input').hide(250) : $('div.input').show(250);
#         window.code_shown = !window.code_shown
#     }
#     if($('body.nbviewer').length) {
#         $('<li><a href="javascript:window.code_toggle()" title="Show/Hide Code"><span class="fa fa-code fa-2x menu-icon"></span><span class="menu-text">Show/Hide Code</span></a></li>').appendTo('.navbar-right');
#         window.code_shown=false;
#         $('div.input').hide();
#     }
# });
# </script>
#
#
# <style>
#
# div.prompt {display:none}
#
#
# h1, .h1 {
#     font-size: 33px;
#     font-family: "Trebuchet MS";
#     font-size: 2.5em !important;
#     color: #2a7bbd;
# }
#
# h2, .h2 {
#     font-size: 10px;
#     font-family: "Trebuchet MS";
#     color: #2a7bbd;
#
# }
#
#
# h3, .h3 {
#     font-size: 10px;
#     font-family: "Trebuchet MS";
#     color: #5d6063;
#
# }
#
# .rendered_html table {
#
#     font-size: 14px;
# }
#
# .output_png {
#   display: flex;
#   justify-content: center;
# }
#
# .cell {
#     padding: 0px;
# }
#
#
# </style>
# Out:
# <script>
# $(document).ready(function(){
#     window.code_toggle = function() {
#         (window.code_shown) ? $('div.input').hide(250) : $('div.input').show(250);
#         window.code_shown = !window.code_shown
#     }
#     if($('body.nbviewer').length) {
#         $('<li><a href="javascript:window.code_toggle()" title="Show/Hide Code"><span class="fa fa-code fa-2x menu-icon"></span><span class="menu-text">Show/Hide Code</span></a></li>').appendTo('.navbar-right');
#         window.code_shown=false;
#         $('div.input').hide();
#     }
# });
# </script>
#
#
# <style>
#
# div.prompt {display:none}
#
#
# h1, .h1 {
#     font-size: 33px;
#     font-family: "Trebuchet MS";
#     font-size: 2.5em !important;
#     color: #2a7bbd;
# }
#
# h2, .h2 {
#     font-size: 10px;
#     font-family: "Trebuchet MS";
#     color: #2a7bbd;
#
# }
#
#
# h3, .h3 {
#     font-size: 10px;
#     font-family: "Trebuchet MS";
#     color: #5d6063;
#
# }
#
# .rendered_html table {
#
#     font-size: 14px;
# }
#
# .output_png {
#   display: flex;
#   justify-content: center;
# }
#
# .cell {
#     padding: 0px;
# }
#
#
# </style>
